# %%
import geopandas as gpd
import matplotlib.pyplot as plt

national_park_checkpost_shpfile = "Bardia_Guard_Post84/"
national_park_shpfile = "Bardia_National_Park/"

# Read the GeoDataFrames from the shapefiles
gdf = gpd.read_file(national_park_checkpost_shpfile)
national_gdf = gpd.read_file(national_park_shpfile)

buffer = 0.02 # Assuming the buffer distance is 5000 meters (adjust as needed)

# Check the current CRS of the GeoDataFrame
print("Original CRS:", gdf.crs)

# Reproject to a suitable projected CRS
projected_crs = 'EPSG:4326'  # UTM zone 33N, replace with an appropriate CRS for your region
gdf = gdf.to_crs(projected_crs)
national_gdf = national_gdf.to_crs(projected_crs)

# Create the buffer using the projected CRS
gdf['buffer'] = gdf.geometry.buffer(buffer)

# Plot the result
ax = national_gdf.plot(edgecolor='red', linewidth=2)
gdf['buffer'].plot(ax=ax, alpha=0.5, color='orange')
plt.title('Buffered Check Posts')
plt.show()
# Out:
# Original CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH],AUTHORITY["EPSG","4326"]]
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14684\1583093833.py:22: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['buffer'] = gdf.geometry.buffer(buffer)
